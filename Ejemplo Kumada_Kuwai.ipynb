# %%
install.packages("igraph")
# Out:
#   There is a binary version available but the source version is later:
#        binary source needs_compilation
# igraph  1.2.6 1.2.11              TRUE
#
#   Binaries will be installed
# package 'igraph' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\moiil\AppData\Local\Temp\RtmpkRpe5c\downloaded_packages

# %%
library (igraph)
# Out:
# Warning message:
# "package 'igraph' was built under R version 3.6.3"
# Attaching package: 'igraph'
#
# The following objects are masked from 'package:stats':
#
#     decompose, spectrum
#
# The following object is masked from 'package:base':
#
#     union

# %%
g <- graph_from_literal(A--D, B--C, C--A, E--A, C--E, E--B)
print(g)
# Out:
# IGRAPH 628e236 UN-- 5 6 --
# + attr: name (v/c)
# + edges from 628e236 (vertex names):
# [1] A--D A--C A--E B--C B--E C--E

# %%
g <- graph_from_literal(A-+D, B++C, C+-A, E+-A, C-+E, E-+B)
print(g)
# Out:
# IGRAPH 6293539 DN-- 5 7 --
# + attr: name (v/c)
# + edges from 6293539 (vertex names):
# [1] A->D A->C A->E B->C C->B C->E E->B

# %%
g <- graph_from_literal(Daniel-+Andres, 
                       Teresa++Carlos, 
                       Carlos+-Daniel, 
                       Elena+-Daniel, 
                       Carlos-+Elena, 
                       Elena-+Teresa)
print(g)
# Out:
# IGRAPH 629612b DN-- 5 7 --
# + attr: name (v/c)
# + edges from 629612b (vertex names):
# [1] Daniel->Andres Daniel->Carlos Daniel->Elena  Teresa->Carlos Carlos->Teresa
# [6] Carlos->Elena  Elena ->Teresa

# %%
plot(g)
# Out:
# Plot with title ""

# %%
plot(g, edge.arrow.size=0.5, vertex.color="red", vertex.size=25, 
     vertex.label.color="black", vertex.label.dist=3, edge.curved=0.2)
# Out:
# Plot with title ""

# %% [markdown]
# Modificar la representación gráfica

# %%
g <- sample_gnm(n=50, m=75)
V(g)$label <- ""
V(g)$size <- 8
plot(g)
# Out:
# Plot with title ""

# %% [markdown]
# igraph tiene la posibilidad de usar uno de los algoritmos como un parámetro más de la función o podemos pasar a la función la localización de los nodos. Por ejemplo:

# %%
plot(g, layout=layout_randomly)
# Out:
# Plot with title ""

# %% [markdown]
# o

# %%
pos <- layout_in_circle(g)
head(pos)
plot(g, layout=pos)
# Out:
#      [,1]      [,2]
# [1,] 1.0000000 0.0000000
# [2,] 0.9921147 0.1253332
# [3,] 0.9685832 0.2486899
# [4,] 0.9297765 0.3681246
# [5,] 0.8763067 0.4817537
# [6,] 0.8090170 0.5877853
# Plot with title ""

# %% [markdown]
# Los dos modos de layout que más nos interesan son los que utilizan para la disposición de los nodos bien un algoritmo o un modelo de escalado.
#
# Una alternativa  es el algoritmo de Kamada-Kawai, que suele usarse como estimación iniciar para el cálculo de las localizaciones de Fruchterman-Reingold ya que es mucho más rápido:

# %%
plot(g, layout=layout_with_fr)
# Out:
# Plot with title ""

# %%
plot(g, layout=layout_with_kk)
# Out:
# Plot with title ""

# %%
plot(g, layout=layout_with_mds)
# Out:
# Plot with title ""
